# %%
import pandas as pd
import numpy as np
import copy
import pydash

# %%
df = pd.DataFrame({'key1':['a', 'a', 'b', 'b', 'a'],
     'key2':['one', 'two', 'one', 'two', 'one'],
     'data1':np.random.randn(5),
     'data2':np.random.randn(5)})

# %%
YEAR_LIST = ['2011', '2012', '2013', '2014', '2015',
             '2016', '2017', '2018', '2019', '2020',
             '2021', '2022', '2023', '2024', '2025',
             '2026', '2027', '2028', '2029', '2030'
             ]


COL_NAME_DICT = {
    'Company Name': "gold_company_name",
    'Field ID': 'gold_field_code',
    'Field Name': 'gold_field_name',
    'Name in Case': 'gold_name_in_case',
    # 'Year1'
    # 'Year2'
    'Unit': 'gold_unit',
    'Type(E/R/C)': 'gold_type',
    'Table': 'gold_table',
    'Chapter': 'gold_chapter',
    'page no': 'gold_page_id'
}

# %%
def trim_all_columns(df):
    """
    Trim whitespace from ends of each value across all series in dataframe
    """
    trim_strings = lambda x: x.strip() if isinstance(x, str) else x
    return df.applymap(trim_strings)

def get_year_list_and_gold_df(file_name):

    year_list = []

    def get_year(col_name):
        if not col_name.strip().startswith("E"):
            return None
        for year in YEAR_LIST:
            if year in col_name:
                return year
        return None

    df = pd.read_csv(file_name)
    df = df.dropna(axis=0, how='all')
    # df = df.dropna(subset=[file_name_col])
    df = df.fillna("")

    col_mapping_dict = {}

    for csv_col_name in df.columns:
        for key, value in COL_NAME_DICT.items():
            if key not in csv_col_name:
                continue
            else:
                col_mapping_dict[csv_col_name] = value
                break
    for csv_col_name in df.columns:
        year = get_year(csv_col_name)
        if not year:
            continue
        year_list.append(year)
        col_mapping_dict[csv_col_name] = year

    df = df.loc[:, list(col_mapping_dict)]
    df = df.rename(columns=col_mapping_dict)
    
    gold_df = trim_all_columns(df)
    gold_df = gold_df[gold_df.gold_field_code.isin(['E_PL_1', 'E_PL_2'])]
    
    return year_list, gold_df

def get_gold_list(year_list, gold_df):
    gold_tmp_list = gold_df.to_dict("record")
    gold_list = []
    for gold_item in gold_tmp_list:
        tmp_item = copy.deepcopy(gold_item)
        for year in year_list:
            tmp_item.pop(year)

        for year in year_list:
            gold_value = gold_item[year]
            nc_item = copy.deepcopy(tmp_item)
            nc_item["gold_value"] = gold_value
            nc_item["gold_year"] = year

            gold_list.append(nc_item)
    return gold_list

def get_gold_dict_for_year_code(gold_list):

    gold_dict = {}

    gold_year_dict = pydash.group_by(gold_list, ["gold_year"])

    for year, one_year_item_list in gold_year_dict.items():
        y_item_list = [item for item in one_year_item_list if item.get("gold_page_id") != "" and item.get("gold_value") != ""]
        # one_year_dict = pydash.group_by(one_year_info, ["gold_field_code"])
        gold_dict[year] = y_item_list
    return gold_dict

# %%
path = '/Users/blair/ghome/6E/work_project/mlar/mlar_offline_dashboard/data/golden_csv'
file_name = f'{path}/Singtel AR 2019.pdf - Human.csv'
year_list, gold_df = get_year_list_and_gold_df(file_name)

gold_list = get_gold_list(year_list, gold_df)
gold_dict = get_gold_dict_for_year_code(gold_list)
gold_dict
# Out:
# {'2019': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': '',
#    'gold_page_id': '140',
#    'gold_value': '17,371.7',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'OPERATING REVENUE',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': '170',
#    'gold_value': '17,371.7',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Group operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'OPERATING REVENUE',
#    'gold_chapter': 'Group Five-year Financial Summary',
#    'gold_page_id': '110',
#    'gold_value': '17,372',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SEGMENT INFORMATION',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': '231',
#    'gold_value': '17,371.7',
#    'gold_year': '2019'}],
#  '2018': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': '',
#    'gold_page_id': '140',
#    'gold_value': '17,268.0',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'OPERATING REVENUE',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': '170',
#    'gold_value': '17,268.0',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Group operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'OPERATING REVENUE',
#    'gold_chapter': 'Group Five-year Financial Summary',
#    'gold_page_id': '110',
#    'gold_value': '17,268',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SEGMENT INFORMATION',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': '232',
#    'gold_value': '17,268.0',
#    'gold_year': '2018'}]}

# %%
gold_year_dict
# Out:
# {'2019': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': '',
#    'gold_page_id': 140.0,
#    'gold_value': '17,371.7',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'OPERATING REVENUE',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 170.0,
#    'gold_value': '17,371.7',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Group operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'OPERATING REVENUE',
#    'gold_chapter': 'Group Five-year Financial Summary',
#    'gold_page_id': 110.0,
#    'gold_value': '17,372',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SEGMENT INFORMATION',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 231.0,
#    'gold_value': '17,371.7',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SEGMENT INFORMATION',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 232.0,
#    'gold_value': '',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_2',
#    'gold_field_name': 'Cost of Sales',
#    'gold_name_in_case': '',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': '',
#    'gold_chapter': '',
#    'gold_page_id': '',
#    'gold_value': '',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_3',
#    'gold_field_name': 'Other cost of revenues',
#    'gold_name_in_case': 'Other cost of sales',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'OPERATING EXPENSES',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 170.0,
#    'gold_value': '2,767.10',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_4',
#    'gold_field_name': 'Transportation Expense',
#    'gold_name_in_case': 'Traffic expenses',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'OPERATING EXPENSES',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 170.0,
#    'gold_value': '1,573.4',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_5',
#    'gold_field_name': 'GROSS PROFIT',
#    'gold_name_in_case': '',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': '',
#    'gold_chapter': '',
#    'gold_page_id': '',
#    'gold_value': '',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_11',
#    'gold_field_name': 'Depreciation',
#    'gold_name_in_case': 'Depreciation of property, plant and equipment ',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'DEPRECIATION AND AMORTISATION',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 182.0,
#    'gold_value': '1,896.1',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_11',
#    'gold_field_name': 'Depreciation',
#    'gold_name_in_case': 'Depreciation charge for the year',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'PROPERTY, PLANT AND EQUIPMENT',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 198.0,
#    'gold_value': '1,896.1',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_11',
#    'gold_field_name': 'Depreciation',
#    'gold_name_in_case': 'Depreciation charge for the year',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'PROPERTY, PLANT AND EQUIPMENT',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 199.0,
#    'gold_value': '',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_12',
#    'gold_field_name': 'Amortisation & Noncash Items',
#    'gold_name_in_case': 'Amortisation of intangible assets',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'DEPRECIATION AND AMORTISATION',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 182.0,
#    'gold_value': '326.1',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_12',
#    'gold_field_name': 'Amortisation & Noncash Items',
#    'gold_name_in_case': 'Amortisation of deferred gain on sale of a joint venture',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'DEPRECIATION AND AMORTISATION',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 182.0,
#    'gold_value': '',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_21',
#    'gold_field_name': 'Interest expense',
#    'gold_name_in_case': 'Finance costs',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': '',
#    'gold_page_id': 140.0,
#    'gold_value': '(392.8)',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_21',
#    'gold_field_name': 'Interest expense',
#    'gold_name_in_case': 'Finance costs',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Statement of Cash Flows',
#    'gold_chapter': '',
#    'gold_page_id': 147.0,
#    'gold_value': '(392.8)',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_21',
#    'gold_field_name': 'Interest expense',
#    'gold_name_in_case': 'Finance costs',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'FINANCE COSTS',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 184.0,
#    'gold_value': '(392.8)',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_21',
#    'gold_field_name': 'Interest expense',
#    'gold_name_in_case': 'Finance costs',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SEGMENT INFORMATION',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 233.0,
#    'gold_value': '(392.8)',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_37',
#    'gold_field_name': 'Taxation',
#    'gold_name_in_case': 'Tax expense',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 140.0,
#    'gold_value': '(674.8)',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_37',
#    'gold_field_name': 'Taxation',
#    'gold_name_in_case': 'Tax expense',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 184.0,
#    'gold_value': '(674.8)',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_38',
#    'gold_field_name': 'NET PROFIT',
#    'gold_name_in_case': '"Attributable to:\nShareholders of the Company"',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': '',
#    'gold_page_id': 140.0,
#    'gold_value': '3,094.50',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_38',
#    'gold_field_name': 'NET PROFIT',
#    'gold_name_in_case': 'Total comprehensive (loss)/ income for the year',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Statements of Changes in Equity',
#    'gold_chapter': '',
#    'gold_page_id': 143.0,
#    'gold_value': '3,094.50',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_39',
#    'gold_field_name': 'Minority Interest',
#    'gold_name_in_case': 'Non-controlling interests',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': '',
#    'gold_page_id': 140.0,
#    'gold_value': '(23.4)',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_43',
#    'gold_field_name': 'EBITDA',
#    'gold_name_in_case': 'Group EBITDA',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': 'Group Five-year Financial Summary',
#    'gold_chapter': '',
#    'gold_page_id': 110.0,
#    'gold_value': '4,692',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_43',
#    'gold_field_name': 'EBITDA',
#    'gold_name_in_case': 'EBITDA',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': 'Management Discussion and Analysis',
#    'gold_chapter': '',
#    'gold_page_id': 114.0,
#    'gold_value': '4,692',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_2',
#    'gold_field_name': 'TOTAL CURRENT ASSETS',
#    'gold_name_in_case': 'Current assets',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Statements of Financial Position',
#    'gold_chapter': '',
#    'gold_page_id': 142.0,
#    'gold_value': '7,078.1',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_2',
#    'gold_field_name': 'TOTAL CURRENT ASSETS',
#    'gold_name_in_case': 'Current assets',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SUMMARY STATEMENTS OF FINANCIAL POSITION',
#    'gold_chapter': '',
#    'gold_page_id': 121.0,
#    'gold_value': '7,078',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_60',
#    'gold_field_name': 'TOTAL LIABILITIES',
#    'gold_name_in_case': 'Total liabilities',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Statements of Financial Position',
#    'gold_chapter': '',
#    'gold_page_id': 142.0,
#    'gold_value': '19,105.1',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_60',
#    'gold_field_name': 'TOTAL LIABILITIES',
#    'gold_name_in_case': 'Total liabilities',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SUMMARY STATEMENTS OF FINANCIAL POSITION',
#    'gold_chapter': '',
#    'gold_page_id': 121.0,
#    'gold_value': '19,105',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_61',
#    'gold_field_name': 'TOTAL CURRENT LIABILITIES',
#    'gold_name_in_case': 'Current liabilities',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Statements of Financial Position',
#    'gold_chapter': '',
#    'gold_page_id': 142.0,
#    'gold_value': '8,794.4',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_61',
#    'gold_field_name': 'TOTAL CURRENT LIABILITIES',
#    'gold_name_in_case': 'Current liabilities',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SUMMARY STATEMENTS OF FINANCIAL POSITION',
#    'gold_chapter': '',
#    'gold_page_id': 121.0,
#    'gold_value': '8,794',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_62',
#    'gold_field_name': 'Short-term borrowings',
#    'gold_name_in_case': 'Bank loans',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'BORROWINGS (UNSECURED)',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 214.0,
#    'gold_value': '1,167.7',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_62',
#    'gold_field_name': 'Short-term borrowings',
#    'gold_name_in_case': 'Current ',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Bank Loans',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 216.0,
#    'gold_value': '1,167.7',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_87',
#    'gold_field_name': 'Current portion of long-term liabilities',
#    'gold_name_in_case': '“Current\n Bonds”',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'BORROWINGS (UNSECURED)',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 214.0,
#    'gold_value': '678.5',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_87',
#    'gold_field_name': 'Current portion of long-term liabilities',
#    'gold_name_in_case': '“Classified as –\n Current”',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Bonds',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 215.0,
#    'gold_value': '678.5',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_92',
#    'gold_field_name': 'Long-Term Debt',
#    'gold_name_in_case': 'Borrowings (Unsecured)',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'BORROWINGS (UNSECURED)',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 214.0,
#    'gold_value': '8,734.4',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_92',
#    'gold_field_name': 'Long-Term Debt',
#    'gold_name_in_case': 'Borrowings (Unsecured)',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Maturity',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 216.0,
#    'gold_value': '8,734.4',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_92',
#    'gold_field_name': 'Long-Term Debt',
#    'gold_name_in_case': 'Borrowings (Unsecured)',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Statements of Financial Position',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 142.0,
#    'gold_value': '8,734.4',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_104',
#    'gold_field_name': 'TOTAL NET WORTH',
#    'gold_name_in_case': 'Total equity',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Statements of Financial Position',
#    'gold_chapter': '',
#    'gold_page_id': 142.0,
#    'gold_value': '29,809.7',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_104',
#    'gold_field_name': 'TOTAL NET WORTH',
#    'gold_name_in_case': 'Total equity',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Statements of Changes in Equity',
#    'gold_chapter': '',
#    'gold_page_id': 143.0,
#    'gold_value': '29,809.7',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_104',
#    'gold_field_name': 'TOTAL NET WORTH',
#    'gold_name_in_case': 'Total equity',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SUMMARY STATEMENTS OF FINANCIAL POSITION',
#    'gold_chapter': '',
#    'gold_page_id': 121.0,
#    'gold_value': '29,810',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_115',
#    'gold_field_name': 'Working Capital',
#    'gold_name_in_case': '',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': '',
#    'gold_chapter': '',
#    'gold_page_id': '',
#    'gold_value': '',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_117',
#    'gold_field_name': 'Total Debt',
#    'gold_name_in_case': 'Net debt',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': '“Management Discussion and Analysis\nCAPITAL MANAGEMENT AND DIVIDEND POLICY”',
#    'gold_chapter': '',
#    'gold_page_id': 122.0,
#    'gold_value': '9,883',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_117',
#    'gold_field_name': 'Total Debt',
#    'gold_name_in_case': 'Net debt',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': 'Group Five-year Financial Summary',
#    'gold_chapter': '',
#    'gold_page_id': 110.0,
#    'gold_value': '9,883',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PRO_4',
#    'gold_field_name': 'EBITDA Margin',
#    'gold_name_in_case': 'EBITDA margin',
#    'gold_unit': '',
#    'gold_type': 'C',
#    'gold_table': 'Management Discussion and Analysis',
#    'gold_chapter': '',
#    'gold_page_id': 114.0,
#    'gold_value': '27.0%',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_COV_8',
#    'gold_field_name': 'Total Debt/EBITDA',
#    'gold_name_in_case': 'Net debt to EBITDA and share of associates’ pre-tax profits (number of times) ',
#    'gold_unit': '',
#    'gold_type': 'C',
#    'gold_table': '“Management Discussion and Analysis\nCAPITAL MANAGEMENT AND DIVIDEND POLICY”',
#    'gold_chapter': '',
#    'gold_page_id': 122.0,
#    'gold_value': '1.6',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_COV_8',
#    'gold_field_name': 'Total Debt/EBITDA',
#    'gold_name_in_case': 'Net debt to EBITDA and share of associates’ pre-tax profits (number of times) ',
#    'gold_unit': '',
#    'gold_type': 'C',
#    'gold_table': 'Group Five-year Financial Summary',
#    'gold_chapter': '',
#    'gold_page_id': 110.0,
#    'gold_value': '1.6',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_LIQ_4',
#    'gold_field_name': 'Total Liabs/Total Net Worth',
#    'gold_name_in_case': '',
#    'gold_unit': '',
#    'gold_type': 'C',
#    'gold_table': '',
#    'gold_chapter': '',
#    'gold_page_id': '',
#    'gold_value': '',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_LIQ_1',
#    'gold_field_name': 'Current Ratio',
#    'gold_name_in_case': '',
#    'gold_unit': '',
#    'gold_type': 'C',
#    'gold_table': '',
#    'gold_chapter': '',
#    'gold_page_id': '',
#    'gold_value': '',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_4',
#    'gold_field_name': 'Trade and Other Receivables',
#    'gold_name_in_case': 'Trade and other receivables',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': 'Statements of Financial Position',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 142.0,
#    'gold_value': '5,992.7',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_4',
#    'gold_field_name': 'Trade and Other Receivables',
#    'gold_name_in_case': 'Trade and other receivables',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': 'TRADE AND OTHER RECEIVABLES',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 192.0,
#    'gold_value': '5,992.7',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_5',
#    'gold_field_name': 'Trade Debtors',
#    'gold_name_in_case': 'Trade receivables',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'TRADE AND OTHER RECEIVABLES',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 192.0,
#    'gold_value': '2,341.3',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_6',
#    'gold_field_name': 'Notes Receivables',
#    'gold_name_in_case': '',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': '',
#    'gold_chapter': '',
#    'gold_page_id': '',
#    'gold_value': '',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_7',
#    'gold_field_name': 'Other Receivables',
#    'gold_name_in_case': 'Other receivables',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'TRADE AND OTHER RECEIVABLES',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 192.0,
#    'gold_value': '421.9',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_ACT_7',
#    'gold_field_name': 'Days of Sales Outstanding',
#    'gold_name_in_case': '',
#    'gold_unit': 'days',
#    'gold_type': 'C',
#    'gold_table': '',
#    'gold_chapter': '',
#    'gold_page_id': '',
#    'gold_value': '',
#    'gold_year': '2019'}],
#  '2018': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': '',
#    'gold_page_id': 140.0,
#    'gold_value': '17,268.0',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'OPERATING REVENUE',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 170.0,
#    'gold_value': '17,268.0',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Group operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'OPERATING REVENUE',
#    'gold_chapter': 'Group Five-year Financial Summary',
#    'gold_page_id': 110.0,
#    'gold_value': '17,268',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SEGMENT INFORMATION',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 231.0,
#    'gold_value': '',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SEGMENT INFORMATION',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 232.0,
#    'gold_value': '17,268.0',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_2',
#    'gold_field_name': 'Cost of Sales',
#    'gold_name_in_case': '',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': '',
#    'gold_chapter': '',
#    'gold_page_id': '',
#    'gold_value': '',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_3',
#    'gold_field_name': 'Other cost of revenues',
#    'gold_name_in_case': 'Other cost of sales',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'OPERATING EXPENSES',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 170.0,
#    'gold_value': '2,499.20',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_4',
#    'gold_field_name': 'Transportation Expense',
#    'gold_name_in_case': 'Traffic expenses',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'OPERATING EXPENSES',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 170.0,
#    'gold_value': '1,615.8',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_5',
#    'gold_field_name': 'GROSS PROFIT',
#    'gold_name_in_case': '',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': '',
#    'gold_chapter': '',
#    'gold_page_id': '',
#    'gold_value': '',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_11',
#    'gold_field_name': 'Depreciation',
#    'gold_name_in_case': 'Depreciation of property, plant and equipment ',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'DEPRECIATION AND AMORTISATION',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 182.0,
#    'gold_value': '1,951.0',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_11',
#    'gold_field_name': 'Depreciation',
#    'gold_name_in_case': 'Depreciation charge for the year',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'PROPERTY, PLANT AND EQUIPMENT',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 198.0,
#    'gold_value': '',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_11',
#    'gold_field_name': 'Depreciation',
#    'gold_name_in_case': 'Depreciation charge for the year',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'PROPERTY, PLANT AND EQUIPMENT',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 199.0,
#    'gold_value': '1,951.0',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_12',
#    'gold_field_name': 'Amortisation & Noncash Items',
#    'gold_name_in_case': 'Amortisation of intangible assets',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'DEPRECIATION AND AMORTISATION',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 182.0,
#    'gold_value': '300.5',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_12',
#    'gold_field_name': 'Amortisation & Noncash Items',
#    'gold_name_in_case': 'Amortisation of deferred gain on sale of a joint venture',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'DEPRECIATION AND AMORTISATION',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 182.0,
#    'gold_value': '(1.5)',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_21',
#    'gold_field_name': 'Interest expense',
#    'gold_name_in_case': 'Finance costs',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': '',
#    'gold_page_id': 140.0,
#    'gold_value': '(390.2)',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_21',
#    'gold_field_name': 'Interest expense',
#    'gold_name_in_case': 'Finance costs',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Statement of Cash Flows',
#    'gold_chapter': '',
#    'gold_page_id': 147.0,
#    'gold_value': '(390.2)',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_21',
#    'gold_field_name': 'Interest expense',
#    'gold_name_in_case': 'Finance costs',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'FINANCE COSTS',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 184.0,
#    'gold_value': '(390.2)',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_21',
#    'gold_field_name': 'Interest expense',
#    'gold_name_in_case': 'Finance costs',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SEGMENT INFORMATION',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 233.0,
#    'gold_value': '(390.2)',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_37',
#    'gold_field_name': 'Taxation',
#    'gold_name_in_case': 'Tax expense',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 140.0,
#    'gold_value': '(703.0)',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_37',
#    'gold_field_name': 'Taxation',
#    'gold_name_in_case': 'Tax expense',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 184.0,
#    'gold_value': '(703.0)',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_38',
#    'gold_field_name': 'NET PROFIT',
#    'gold_name_in_case': '"Attributable to:\nShareholders of the Company"',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': '',
#    'gold_page_id': 140.0,
#    'gold_value': '5,473.00',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_38',
#    'gold_field_name': 'NET PROFIT',
#    'gold_name_in_case': 'Total comprehensive (loss)/ income for the year',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Statements of Changes in Equity',
#    'gold_chapter': '',
#    'gold_page_id': 143.0,
#    'gold_value': '5,473.00',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_39',
#    'gold_field_name': 'Minority Interest',
#    'gold_name_in_case': 'Non-controlling interests',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': '',
#    'gold_page_id': 140.0,
#    'gold_value': '(21.1)',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_43',
#    'gold_field_name': 'EBITDA',
#    'gold_name_in_case': 'Group EBITDA',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': 'Group Five-year Financial Summary',
#    'gold_chapter': '',
#    'gold_page_id': 110.0,
#    'gold_value': '5,051',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_43',
#    'gold_field_name': 'EBITDA',
#    'gold_name_in_case': 'EBITDA',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': 'Management Discussion and Analysis',
#    'gold_chapter': '',
#    'gold_page_id': 114.0,
#    'gold_value': '5,051',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_2',
#    'gold_field_name': 'TOTAL CURRENT ASSETS',
#    'gold_name_in_case': 'Current assets',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Statements of Financial Position',
#    'gold_chapter': '',
#    'gold_page_id': 142.0,
#    'gold_value': '6,758.6',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_2',
#    'gold_field_name': 'TOTAL CURRENT ASSETS',
#    'gold_name_in_case': 'Current assets',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SUMMARY STATEMENTS OF FINANCIAL POSITION',
#    'gold_chapter': '',
#    'gold_page_id': 121.0,
#    'gold_value': '6,759',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_60',
#    'gold_field_name': 'TOTAL LIABILITIES',
#    'gold_name_in_case': 'Total liabilities',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Statements of Financial Position',
#    'gold_chapter': '',
#    'gold_page_id': 142.0,
#    'gold_value': '18,784.0',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_60',
#    'gold_field_name': 'TOTAL LIABILITIES',
#    'gold_name_in_case': 'Total liabilities',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SUMMARY STATEMENTS OF FINANCIAL POSITION',
#    'gold_chapter': '',
#    'gold_page_id': 121.0,
#    'gold_value': '18,784',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_61',
#    'gold_field_name': 'TOTAL CURRENT LIABILITIES',
#    'gold_name_in_case': 'Current liabilities',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Statements of Financial Position',
#    'gold_chapter': '',
#    'gold_page_id': 142.0,
#    'gold_value': '8,429.4',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_61',
#    'gold_field_name': 'TOTAL CURRENT LIABILITIES',
#    'gold_name_in_case': 'Current liabilities',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SUMMARY STATEMENTS OF FINANCIAL POSITION',
#    'gold_chapter': '',
#    'gold_page_id': 121.0,
#    'gold_value': '8,429',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_62',
#    'gold_field_name': 'Short-term borrowings',
#    'gold_name_in_case': 'Bank loans',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'BORROWINGS (UNSECURED)',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 214.0,
#    'gold_value': '671.5',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_62',
#    'gold_field_name': 'Short-term borrowings',
#    'gold_name_in_case': 'Current ',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Bank Loans',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 216.0,
#    'gold_value': '671.5',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_87',
#    'gold_field_name': 'Current portion of long-term liabilities',
#    'gold_name_in_case': '“Current\n Bonds”',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'BORROWINGS (UNSECURED)',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 214.0,
#    'gold_value': '1,129.00',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_87',
#    'gold_field_name': 'Current portion of long-term liabilities',
#    'gold_name_in_case': '“Classified as –\n Current”',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Bonds',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 215.0,
#    'gold_value': '1,129.00',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_92',
#    'gold_field_name': 'Long-Term Debt',
#    'gold_name_in_case': 'Borrowings (Unsecured)',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'BORROWINGS (UNSECURED)',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 214.0,
#    'gold_value': '8,586.1',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_92',
#    'gold_field_name': 'Long-Term Debt',
#    'gold_name_in_case': 'Borrowings (Unsecured)',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Maturity',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 216.0,
#    'gold_value': '8,586.1',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_92',
#    'gold_field_name': 'Long-Term Debt',
#    'gold_name_in_case': 'Borrowings (Unsecured)',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Statements of Financial Position',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 142.0,
#    'gold_value': '8,586.1',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_104',
#    'gold_field_name': 'TOTAL NET WORTH',
#    'gold_name_in_case': 'Total equity',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Statements of Financial Position',
#    'gold_chapter': '',
#    'gold_page_id': 142.0,
#    'gold_value': '29,711.5',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_104',
#    'gold_field_name': 'TOTAL NET WORTH',
#    'gold_name_in_case': 'Total equity',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Statements of Changes in Equity',
#    'gold_chapter': '',
#    'gold_page_id': 143.0,
#    'gold_value': '29,711.5',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_104',
#    'gold_field_name': 'TOTAL NET WORTH',
#    'gold_name_in_case': 'Total equity',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SUMMARY STATEMENTS OF FINANCIAL POSITION',
#    'gold_chapter': '',
#    'gold_page_id': 121.0,
#    'gold_value': '29,712',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_115',
#    'gold_field_name': 'Working Capital',
#    'gold_name_in_case': '',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': '',
#    'gold_chapter': '',
#    'gold_page_id': '',
#    'gold_value': '',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_117',
#    'gold_field_name': 'Total Debt',
#    'gold_name_in_case': 'Net debt',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': '“Management Discussion and Analysis\nCAPITAL MANAGEMENT AND DIVIDEND POLICY”',
#    'gold_chapter': '',
#    'gold_page_id': 122.0,
#    'gold_value': '9,877',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_117',
#    'gold_field_name': 'Total Debt',
#    'gold_name_in_case': 'Net debt',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': 'Group Five-year Financial Summary',
#    'gold_chapter': '',
#    'gold_page_id': 110.0,
#    'gold_value': '9,877',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PRO_4',
#    'gold_field_name': 'EBITDA Margin',
#    'gold_name_in_case': 'EBITDA margin',
#    'gold_unit': '',
#    'gold_type': 'C',
#    'gold_table': 'Management Discussion and Analysis',
#    'gold_chapter': '',
#    'gold_page_id': 114.0,
#    'gold_value': '29.2%',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_COV_8',
#    'gold_field_name': 'Total Debt/EBITDA',
#    'gold_name_in_case': 'Net debt to EBITDA and share of associates’ pre-tax profits (number of times) ',
#    'gold_unit': '',
#    'gold_type': 'C',
#    'gold_table': '“Management Discussion and Analysis\nCAPITAL MANAGEMENT AND DIVIDEND POLICY”',
#    'gold_chapter': '',
#    'gold_page_id': 122.0,
#    'gold_value': '1.3',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_COV_8',
#    'gold_field_name': 'Total Debt/EBITDA',
#    'gold_name_in_case': 'Net debt to EBITDA and share of associates’ pre-tax profits (number of times) ',
#    'gold_unit': '',
#    'gold_type': 'C',
#    'gold_table': 'Group Five-year Financial Summary',
#    'gold_chapter': '',
#    'gold_page_id': 110.0,
#    'gold_value': '1.3',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_LIQ_4',
#    'gold_field_name': 'Total Liabs/Total Net Worth',
#    'gold_name_in_case': '',
#    'gold_unit': '',
#    'gold_type': 'C',
#    'gold_table': '',
#    'gold_chapter': '',
#    'gold_page_id': '',
#    'gold_value': '',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_LIQ_1',
#    'gold_field_name': 'Current Ratio',
#    'gold_name_in_case': '',
#    'gold_unit': '',
#    'gold_type': 'C',
#    'gold_table': '',
#    'gold_chapter': '',
#    'gold_page_id': '',
#    'gold_value': '',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_4',
#    'gold_field_name': 'Trade and Other Receivables',
#    'gold_name_in_case': 'Trade and other receivables',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': 'Statements of Financial Position',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 142.0,
#    'gold_value': '5,813.7',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_4',
#    'gold_field_name': 'Trade and Other Receivables',
#    'gold_name_in_case': 'Trade and other receivables',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': 'TRADE AND OTHER RECEIVABLES',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 192.0,
#    'gold_value': '5,813.7',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_5',
#    'gold_field_name': 'Trade Debtors',
#    'gold_name_in_case': 'Trade receivables',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'TRADE AND OTHER RECEIVABLES',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 192.0,
#    'gold_value': '2,247.6',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_6',
#    'gold_field_name': 'Notes Receivables',
#    'gold_name_in_case': '',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': '',
#    'gold_chapter': '',
#    'gold_page_id': '',
#    'gold_value': '',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_7',
#    'gold_field_name': 'Other Receivables',
#    'gold_name_in_case': 'Other receivables',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'TRADE AND OTHER RECEIVABLES',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 192.0,
#    'gold_value': '430.0',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_ACT_7',
#    'gold_field_name': 'Days of Sales Outstanding',
#    'gold_name_in_case': '',
#    'gold_unit': 'days',
#    'gold_type': 'C',
#    'gold_table': '',
#    'gold_chapter': '',
#    'gold_page_id': '',
#    'gold_value': '',
#    'gold_year': '2018'}]}

# %%
one_year_info = gold_year_dict['2019']

pydash.group_by(one_year_info, ["gold_field_code"])
# Out:
# {'E_PL_1': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': '',
#    'gold_page_id': 140.0,
#    'gold_value': '17,371.7',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'OPERATING REVENUE',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 170.0,
#    'gold_value': '17,371.7',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Group operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'OPERATING REVENUE',
#    'gold_chapter': 'Group Five-year Financial Summary',
#    'gold_page_id': 110.0,
#    'gold_value': '17,372',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SEGMENT INFORMATION',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 231.0,
#    'gold_value': '17,371.7',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SEGMENT INFORMATION',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 232.0,
#    'gold_value': '',
#    'gold_year': '2019'}],
#  'E_PL_2': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_2',
#    'gold_field_name': 'Cost of Sales',
#    'gold_name_in_case': '',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': '',
#    'gold_chapter': '',
#    'gold_page_id': '',
#    'gold_value': '',
#    'gold_year': '2019'}],
#  'E_PL_3': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_3',
#    'gold_field_name': 'Other cost of revenues',
#    'gold_name_in_case': 'Other cost of sales',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'OPERATING EXPENSES',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 170.0,
#    'gold_value': '2,767.10',
#    'gold_year': '2019'}],
#  'E_PL_4': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_4',
#    'gold_field_name': 'Transportation Expense',
#    'gold_name_in_case': 'Traffic expenses',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'OPERATING EXPENSES',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 170.0,
#    'gold_value': '1,573.4',
#    'gold_year': '2019'}],
#  'E_PL_5': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_5',
#    'gold_field_name': 'GROSS PROFIT',
#    'gold_name_in_case': '',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': '',
#    'gold_chapter': '',
#    'gold_page_id': '',
#    'gold_value': '',
#    'gold_year': '2019'}],
#  'E_PL_11': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_11',
#    'gold_field_name': 'Depreciation',
#    'gold_name_in_case': 'Depreciation of property, plant and equipment ',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'DEPRECIATION AND AMORTISATION',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 182.0,
#    'gold_value': '1,896.1',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_11',
#    'gold_field_name': 'Depreciation',
#    'gold_name_in_case': 'Depreciation charge for the year',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'PROPERTY, PLANT AND EQUIPMENT',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 198.0,
#    'gold_value': '1,896.1',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_11',
#    'gold_field_name': 'Depreciation',
#    'gold_name_in_case': 'Depreciation charge for the year',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'PROPERTY, PLANT AND EQUIPMENT',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 199.0,
#    'gold_value': '',
#    'gold_year': '2019'}],
#  'E_PL_12': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_12',
#    'gold_field_name': 'Amortisation & Noncash Items',
#    'gold_name_in_case': 'Amortisation of intangible assets',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'DEPRECIATION AND AMORTISATION',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 182.0,
#    'gold_value': '326.1',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_12',
#    'gold_field_name': 'Amortisation & Noncash Items',
#    'gold_name_in_case': 'Amortisation of deferred gain on sale of a joint venture',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'DEPRECIATION AND AMORTISATION',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 182.0,
#    'gold_value': '',
#    'gold_year': '2019'}],
#  'E_PL_21': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_21',
#    'gold_field_name': 'Interest expense',
#    'gold_name_in_case': 'Finance costs',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': '',
#    'gold_page_id': 140.0,
#    'gold_value': '(392.8)',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_21',
#    'gold_field_name': 'Interest expense',
#    'gold_name_in_case': 'Finance costs',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Statement of Cash Flows',
#    'gold_chapter': '',
#    'gold_page_id': 147.0,
#    'gold_value': '(392.8)',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_21',
#    'gold_field_name': 'Interest expense',
#    'gold_name_in_case': 'Finance costs',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'FINANCE COSTS',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 184.0,
#    'gold_value': '(392.8)',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_21',
#    'gold_field_name': 'Interest expense',
#    'gold_name_in_case': 'Finance costs',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SEGMENT INFORMATION',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 233.0,
#    'gold_value': '(392.8)',
#    'gold_year': '2019'}],
#  'E_PL_37': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_37',
#    'gold_field_name': 'Taxation',
#    'gold_name_in_case': 'Tax expense',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 140.0,
#    'gold_value': '(674.8)',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_37',
#    'gold_field_name': 'Taxation',
#    'gold_name_in_case': 'Tax expense',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 184.0,
#    'gold_value': '(674.8)',
#    'gold_year': '2019'}],
#  'E_PL_38': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_38',
#    'gold_field_name': 'NET PROFIT',
#    'gold_name_in_case': '"Attributable to:\nShareholders of the Company"',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': '',
#    'gold_page_id': 140.0,
#    'gold_value': '3,094.50',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_38',
#    'gold_field_name': 'NET PROFIT',
#    'gold_name_in_case': 'Total comprehensive (loss)/ income for the year',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Statements of Changes in Equity',
#    'gold_chapter': '',
#    'gold_page_id': 143.0,
#    'gold_value': '3,094.50',
#    'gold_year': '2019'}],
#  'E_PL_39': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_39',
#    'gold_field_name': 'Minority Interest',
#    'gold_name_in_case': 'Non-controlling interests',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': '',
#    'gold_page_id': 140.0,
#    'gold_value': '(23.4)',
#    'gold_year': '2019'}],
#  'E_PL_43': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_43',
#    'gold_field_name': 'EBITDA',
#    'gold_name_in_case': 'Group EBITDA',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': 'Group Five-year Financial Summary',
#    'gold_chapter': '',
#    'gold_page_id': 110.0,
#    'gold_value': '4,692',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_43',
#    'gold_field_name': 'EBITDA',
#    'gold_name_in_case': 'EBITDA',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': 'Management Discussion and Analysis',
#    'gold_chapter': '',
#    'gold_page_id': 114.0,
#    'gold_value': '4,692',
#    'gold_year': '2019'}],
#  'E_BS_2': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_2',
#    'gold_field_name': 'TOTAL CURRENT ASSETS',
#    'gold_name_in_case': 'Current assets',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Statements of Financial Position',
#    'gold_chapter': '',
#    'gold_page_id': 142.0,
#    'gold_value': '7,078.1',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_2',
#    'gold_field_name': 'TOTAL CURRENT ASSETS',
#    'gold_name_in_case': 'Current assets',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SUMMARY STATEMENTS OF FINANCIAL POSITION',
#    'gold_chapter': '',
#    'gold_page_id': 121.0,
#    'gold_value': '7,078',
#    'gold_year': '2019'}],
#  'E_BS_60': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_60',
#    'gold_field_name': 'TOTAL LIABILITIES',
#    'gold_name_in_case': 'Total liabilities',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Statements of Financial Position',
#    'gold_chapter': '',
#    'gold_page_id': 142.0,
#    'gold_value': '19,105.1',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_60',
#    'gold_field_name': 'TOTAL LIABILITIES',
#    'gold_name_in_case': 'Total liabilities',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SUMMARY STATEMENTS OF FINANCIAL POSITION',
#    'gold_chapter': '',
#    'gold_page_id': 121.0,
#    'gold_value': '19,105',
#    'gold_year': '2019'}],
#  'E_BS_61': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_61',
#    'gold_field_name': 'TOTAL CURRENT LIABILITIES',
#    'gold_name_in_case': 'Current liabilities',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Statements of Financial Position',
#    'gold_chapter': '',
#    'gold_page_id': 142.0,
#    'gold_value': '8,794.4',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_61',
#    'gold_field_name': 'TOTAL CURRENT LIABILITIES',
#    'gold_name_in_case': 'Current liabilities',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SUMMARY STATEMENTS OF FINANCIAL POSITION',
#    'gold_chapter': '',
#    'gold_page_id': 121.0,
#    'gold_value': '8,794',
#    'gold_year': '2019'}],
#  'E_BS_62': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_62',
#    'gold_field_name': 'Short-term borrowings',
#    'gold_name_in_case': 'Bank loans',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'BORROWINGS (UNSECURED)',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 214.0,
#    'gold_value': '1,167.7',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_62',
#    'gold_field_name': 'Short-term borrowings',
#    'gold_name_in_case': 'Current ',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Bank Loans',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 216.0,
#    'gold_value': '1,167.7',
#    'gold_year': '2019'}],
#  'E_BS_87': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_87',
#    'gold_field_name': 'Current portion of long-term liabilities',
#    'gold_name_in_case': '“Current\n Bonds”',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'BORROWINGS (UNSECURED)',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 214.0,
#    'gold_value': '678.5',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_87',
#    'gold_field_name': 'Current portion of long-term liabilities',
#    'gold_name_in_case': '“Classified as –\n Current”',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Bonds',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 215.0,
#    'gold_value': '678.5',
#    'gold_year': '2019'}],
#  'E_BS_92': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_92',
#    'gold_field_name': 'Long-Term Debt',
#    'gold_name_in_case': 'Borrowings (Unsecured)',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'BORROWINGS (UNSECURED)',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 214.0,
#    'gold_value': '8,734.4',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_92',
#    'gold_field_name': 'Long-Term Debt',
#    'gold_name_in_case': 'Borrowings (Unsecured)',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Maturity',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 216.0,
#    'gold_value': '8,734.4',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_92',
#    'gold_field_name': 'Long-Term Debt',
#    'gold_name_in_case': 'Borrowings (Unsecured)',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Statements of Financial Position',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 142.0,
#    'gold_value': '8,734.4',
#    'gold_year': '2019'}],
#  'E_BS_104': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_104',
#    'gold_field_name': 'TOTAL NET WORTH',
#    'gold_name_in_case': 'Total equity',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Statements of Financial Position',
#    'gold_chapter': '',
#    'gold_page_id': 142.0,
#    'gold_value': '29,809.7',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_104',
#    'gold_field_name': 'TOTAL NET WORTH',
#    'gold_name_in_case': 'Total equity',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Statements of Changes in Equity',
#    'gold_chapter': '',
#    'gold_page_id': 143.0,
#    'gold_value': '29,809.7',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_104',
#    'gold_field_name': 'TOTAL NET WORTH',
#    'gold_name_in_case': 'Total equity',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SUMMARY STATEMENTS OF FINANCIAL POSITION',
#    'gold_chapter': '',
#    'gold_page_id': 121.0,
#    'gold_value': '29,810',
#    'gold_year': '2019'}],
#  'E_BS_115': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_115',
#    'gold_field_name': 'Working Capital',
#    'gold_name_in_case': '',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': '',
#    'gold_chapter': '',
#    'gold_page_id': '',
#    'gold_value': '',
#    'gold_year': '2019'}],
#  'E_BS_117': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_117',
#    'gold_field_name': 'Total Debt',
#    'gold_name_in_case': 'Net debt',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': '“Management Discussion and Analysis\nCAPITAL MANAGEMENT AND DIVIDEND POLICY”',
#    'gold_chapter': '',
#    'gold_page_id': 122.0,
#    'gold_value': '9,883',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_117',
#    'gold_field_name': 'Total Debt',
#    'gold_name_in_case': 'Net debt',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': 'Group Five-year Financial Summary',
#    'gold_chapter': '',
#    'gold_page_id': 110.0,
#    'gold_value': '9,883',
#    'gold_year': '2019'}],
#  'E_PRO_4': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PRO_4',
#    'gold_field_name': 'EBITDA Margin',
#    'gold_name_in_case': 'EBITDA margin',
#    'gold_unit': '',
#    'gold_type': 'C',
#    'gold_table': 'Management Discussion and Analysis',
#    'gold_chapter': '',
#    'gold_page_id': 114.0,
#    'gold_value': '27.0%',
#    'gold_year': '2019'}],
#  'E_COV_8': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_COV_8',
#    'gold_field_name': 'Total Debt/EBITDA',
#    'gold_name_in_case': 'Net debt to EBITDA and share of associates’ pre-tax profits (number of times) ',
#    'gold_unit': '',
#    'gold_type': 'C',
#    'gold_table': '“Management Discussion and Analysis\nCAPITAL MANAGEMENT AND DIVIDEND POLICY”',
#    'gold_chapter': '',
#    'gold_page_id': 122.0,
#    'gold_value': '1.6',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_COV_8',
#    'gold_field_name': 'Total Debt/EBITDA',
#    'gold_name_in_case': 'Net debt to EBITDA and share of associates’ pre-tax profits (number of times) ',
#    'gold_unit': '',
#    'gold_type': 'C',
#    'gold_table': 'Group Five-year Financial Summary',
#    'gold_chapter': '',
#    'gold_page_id': 110.0,
#    'gold_value': '1.6',
#    'gold_year': '2019'}],
#  'E_LIQ_4': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_LIQ_4',
#    'gold_field_name': 'Total Liabs/Total Net Worth',
#    'gold_name_in_case': '',
#    'gold_unit': '',
#    'gold_type': 'C',
#    'gold_table': '',
#    'gold_chapter': '',
#    'gold_page_id': '',
#    'gold_value': '',
#    'gold_year': '2019'}],
#  'E_LIQ_1': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_LIQ_1',
#    'gold_field_name': 'Current Ratio',
#    'gold_name_in_case': '',
#    'gold_unit': '',
#    'gold_type': 'C',
#    'gold_table': '',
#    'gold_chapter': '',
#    'gold_page_id': '',
#    'gold_value': '',
#    'gold_year': '2019'}],
#  'E_BS_4': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_4',
#    'gold_field_name': 'Trade and Other Receivables',
#    'gold_name_in_case': 'Trade and other receivables',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': 'Statements of Financial Position',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 142.0,
#    'gold_value': '5,992.7',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_4',
#    'gold_field_name': 'Trade and Other Receivables',
#    'gold_name_in_case': 'Trade and other receivables',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': 'TRADE AND OTHER RECEIVABLES',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 192.0,
#    'gold_value': '5,992.7',
#    'gold_year': '2019'}],
#  'E_BS_5': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_5',
#    'gold_field_name': 'Trade Debtors',
#    'gold_name_in_case': 'Trade receivables',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'TRADE AND OTHER RECEIVABLES',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 192.0,
#    'gold_value': '2,341.3',
#    'gold_year': '2019'}],
#  'E_BS_6': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_6',
#    'gold_field_name': 'Notes Receivables',
#    'gold_name_in_case': '',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': '',
#    'gold_chapter': '',
#    'gold_page_id': '',
#    'gold_value': '',
#    'gold_year': '2019'}],
#  'E_BS_7': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_7',
#    'gold_field_name': 'Other Receivables',
#    'gold_name_in_case': 'Other receivables',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'TRADE AND OTHER RECEIVABLES',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 192.0,
#    'gold_value': '421.9',
#    'gold_year': '2019'}],
#  'E_ACT_7': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_ACT_7',
#    'gold_field_name': 'Days of Sales Outstanding',
#    'gold_name_in_case': '',
#    'gold_unit': 'days',
#    'gold_type': 'C',
#    'gold_table': '',
#    'gold_chapter': '',
#    'gold_page_id': '',
#    'gold_value': '',
#    'gold_year': '2019'}]}

# %%
gold_list = gold_df.to_dict("record")

pydash.group_by(gold_list, "gold_field_code")
# Out:
# {'E_PL_1': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': '',
#    'gold_page_id': 140.0,
#    '2019': '17,371.7',
#    '2018': '17,268.0'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'OPERATING REVENUE',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 170.0,
#    '2019': '17,371.7',
#    '2018': '17,268.0'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Group operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'OPERATING REVENUE',
#    'gold_chapter': 'Group Five-year Financial Summary',
#    'gold_page_id': 110.0,
#    '2019': '17,372',
#    '2018': '17,268'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SEGMENT INFORMATION',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 231.0,
#    '2019': '17,371.7',
#    '2018': ''},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SEGMENT INFORMATION',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 232.0,
#    '2019': '',
#    '2018': '17,268.0'}],
#  'E_PL_2': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_2',
#    'gold_field_name': 'Cost of Sales',
#    'gold_name_in_case': '',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': '',
#    'gold_chapter': '',
#    'gold_page_id': '',
#    '2019': '',
#    '2018': ''}],
#  'E_PL_3': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_3',
#    'gold_field_name': 'Other cost of revenues',
#    'gold_name_in_case': 'Other cost of sales',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'OPERATING EXPENSES',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 170.0,
#    '2019': '2,767.10',
#    '2018': '2,499.20'}],
#  'E_PL_4': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_4',
#    'gold_field_name': 'Transportation Expense',
#    'gold_name_in_case': 'Traffic expenses',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'OPERATING EXPENSES',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 170.0,
#    '2019': '1,573.4',
#    '2018': '1,615.8'}],
#  'E_PL_5': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_5',
#    'gold_field_name': 'GROSS PROFIT',
#    'gold_name_in_case': '',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': '',
#    'gold_chapter': '',
#    'gold_page_id': '',
#    '2019': '',
#    '2018': ''}],
#  'E_PL_11': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_11',
#    'gold_field_name': 'Depreciation',
#    'gold_name_in_case': 'Depreciation of property, plant and equipment ',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'DEPRECIATION AND AMORTISATION',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 182.0,
#    '2019': '1,896.1',
#    '2018': '1,951.0'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_11',
#    'gold_field_name': 'Depreciation',
#    'gold_name_in_case': 'Depreciation charge for the year',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'PROPERTY, PLANT AND EQUIPMENT',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 198.0,
#    '2019': '1,896.1',
#    '2018': ''},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_11',
#    'gold_field_name': 'Depreciation',
#    'gold_name_in_case': 'Depreciation charge for the year',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'PROPERTY, PLANT AND EQUIPMENT',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 199.0,
#    '2019': '',
#    '2018': '1,951.0'}],
#  'E_PL_12': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_12',
#    'gold_field_name': 'Amortisation & Noncash Items',
#    'gold_name_in_case': 'Amortisation of intangible assets',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'DEPRECIATION AND AMORTISATION',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 182.0,
#    '2019': '326.1',
#    '2018': '300.5'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_12',
#    'gold_field_name': 'Amortisation & Noncash Items',
#    'gold_name_in_case': 'Amortisation of deferred gain on sale of a joint venture',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'DEPRECIATION AND AMORTISATION',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 182.0,
#    '2019': '',
#    '2018': '(1.5)'}],
#  'E_PL_21': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_21',
#    'gold_field_name': 'Interest expense',
#    'gold_name_in_case': 'Finance costs',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': '',
#    'gold_page_id': 140.0,
#    '2019': '(392.8)',
#    '2018': '(390.2)'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_21',
#    'gold_field_name': 'Interest expense',
#    'gold_name_in_case': 'Finance costs',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Statement of Cash Flows',
#    'gold_chapter': '',
#    'gold_page_id': 147.0,
#    '2019': '(392.8)',
#    '2018': '(390.2)'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_21',
#    'gold_field_name': 'Interest expense',
#    'gold_name_in_case': 'Finance costs',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'FINANCE COSTS',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 184.0,
#    '2019': '(392.8)',
#    '2018': '(390.2)'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_21',
#    'gold_field_name': 'Interest expense',
#    'gold_name_in_case': 'Finance costs',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SEGMENT INFORMATION',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 233.0,
#    '2019': '(392.8)',
#    '2018': '(390.2)'}],
#  'E_PL_37': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_37',
#    'gold_field_name': 'Taxation',
#    'gold_name_in_case': 'Tax expense',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 140.0,
#    '2019': '(674.8)',
#    '2018': '(703.0)'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_37',
#    'gold_field_name': 'Taxation',
#    'gold_name_in_case': 'Tax expense',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 184.0,
#    '2019': '(674.8)',
#    '2018': '(703.0)'}],
#  'E_PL_38': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_38',
#    'gold_field_name': 'NET PROFIT',
#    'gold_name_in_case': '"Attributable to:\nShareholders of the Company"',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': '',
#    'gold_page_id': 140.0,
#    '2019': '3,094.50',
#    '2018': '5,473.00'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_38',
#    'gold_field_name': 'NET PROFIT',
#    'gold_name_in_case': 'Total comprehensive (loss)/ income for the year',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Statements of Changes in Equity',
#    'gold_chapter': '',
#    'gold_page_id': 143.0,
#    '2019': '3,094.50',
#    '2018': '5,473.00'}],
#  'E_PL_39': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_39',
#    'gold_field_name': 'Minority Interest',
#    'gold_name_in_case': 'Non-controlling interests',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': '',
#    'gold_page_id': 140.0,
#    '2019': '(23.4)',
#    '2018': '(21.1)'}],
#  'E_PL_43': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_43',
#    'gold_field_name': 'EBITDA',
#    'gold_name_in_case': 'Group EBITDA',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': 'Group Five-year Financial Summary',
#    'gold_chapter': '',
#    'gold_page_id': 110.0,
#    '2019': '4,692',
#    '2018': '5,051'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_43',
#    'gold_field_name': 'EBITDA',
#    'gold_name_in_case': 'EBITDA',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': 'Management Discussion and Analysis',
#    'gold_chapter': '',
#    'gold_page_id': 114.0,
#    '2019': '4,692',
#    '2018': '5,051'}],
#  'E_BS_2': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_2',
#    'gold_field_name': 'TOTAL CURRENT ASSETS',
#    'gold_name_in_case': 'Current assets',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Statements of Financial Position',
#    'gold_chapter': '',
#    'gold_page_id': 142.0,
#    '2019': '7,078.1',
#    '2018': '6,758.6'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_2',
#    'gold_field_name': 'TOTAL CURRENT ASSETS',
#    'gold_name_in_case': 'Current assets',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SUMMARY STATEMENTS OF FINANCIAL POSITION',
#    'gold_chapter': '',
#    'gold_page_id': 121.0,
#    '2019': '7,078',
#    '2018': '6,759'}],
#  'E_BS_60': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_60',
#    'gold_field_name': 'TOTAL LIABILITIES',
#    'gold_name_in_case': 'Total liabilities',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Statements of Financial Position',
#    'gold_chapter': '',
#    'gold_page_id': 142.0,
#    '2019': '19,105.1',
#    '2018': '18,784.0'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_60',
#    'gold_field_name': 'TOTAL LIABILITIES',
#    'gold_name_in_case': 'Total liabilities',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SUMMARY STATEMENTS OF FINANCIAL POSITION',
#    'gold_chapter': '',
#    'gold_page_id': 121.0,
#    '2019': '19,105',
#    '2018': '18,784'}],
#  'E_BS_61': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_61',
#    'gold_field_name': 'TOTAL CURRENT LIABILITIES',
#    'gold_name_in_case': 'Current liabilities',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Statements of Financial Position',
#    'gold_chapter': '',
#    'gold_page_id': 142.0,
#    '2019': '8,794.4',
#    '2018': '8,429.4'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_61',
#    'gold_field_name': 'TOTAL CURRENT LIABILITIES',
#    'gold_name_in_case': 'Current liabilities',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SUMMARY STATEMENTS OF FINANCIAL POSITION',
#    'gold_chapter': '',
#    'gold_page_id': 121.0,
#    '2019': '8,794',
#    '2018': '8,429'}],
#  'E_BS_62': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_62',
#    'gold_field_name': 'Short-term borrowings',
#    'gold_name_in_case': 'Bank loans',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'BORROWINGS (UNSECURED)',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 214.0,
#    '2019': '1,167.7',
#    '2018': '671.5'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_62',
#    'gold_field_name': 'Short-term borrowings',
#    'gold_name_in_case': 'Current ',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Bank Loans',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 216.0,
#    '2019': '1,167.7',
#    '2018': '671.5'}],
#  'E_BS_87': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_87',
#    'gold_field_name': 'Current portion of long-term liabilities',
#    'gold_name_in_case': '“Current\n Bonds”',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'BORROWINGS (UNSECURED)',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 214.0,
#    '2019': '678.5',
#    '2018': '1,129.00'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_87',
#    'gold_field_name': 'Current portion of long-term liabilities',
#    'gold_name_in_case': '“Classified as –\n Current”',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Bonds',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 215.0,
#    '2019': '678.5',
#    '2018': '1,129.00'}],
#  'E_BS_92': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_92',
#    'gold_field_name': 'Long-Term Debt',
#    'gold_name_in_case': 'Borrowings (Unsecured)',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'BORROWINGS (UNSECURED)',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 214.0,
#    '2019': '8,734.4',
#    '2018': '8,586.1'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_92',
#    'gold_field_name': 'Long-Term Debt',
#    'gold_name_in_case': 'Borrowings (Unsecured)',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Maturity',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 216.0,
#    '2019': '8,734.4',
#    '2018': '8,586.1'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_92',
#    'gold_field_name': 'Long-Term Debt',
#    'gold_name_in_case': 'Borrowings (Unsecured)',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Statements of Financial Position',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 142.0,
#    '2019': '8,734.4',
#    '2018': '8,586.1'}],
#  'E_BS_104': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_104',
#    'gold_field_name': 'TOTAL NET WORTH',
#    'gold_name_in_case': 'Total equity',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Statements of Financial Position',
#    'gold_chapter': '',
#    'gold_page_id': 142.0,
#    '2019': '29,809.7',
#    '2018': '29,711.5'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_104',
#    'gold_field_name': 'TOTAL NET WORTH',
#    'gold_name_in_case': 'Total equity',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Statements of Changes in Equity',
#    'gold_chapter': '',
#    'gold_page_id': 143.0,
#    '2019': '29,809.7',
#    '2018': '29,711.5'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_104',
#    'gold_field_name': 'TOTAL NET WORTH',
#    'gold_name_in_case': 'Total equity',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'SUMMARY STATEMENTS OF FINANCIAL POSITION',
#    'gold_chapter': '',
#    'gold_page_id': 121.0,
#    '2019': '29,810',
#    '2018': '29,712'}],
#  'E_BS_115': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_115',
#    'gold_field_name': 'Working Capital',
#    'gold_name_in_case': '',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': '',
#    'gold_chapter': '',
#    'gold_page_id': '',
#    '2019': '',
#    '2018': ''}],
#  'E_BS_117': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_117',
#    'gold_field_name': 'Total Debt',
#    'gold_name_in_case': 'Net debt',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': '“Management Discussion and Analysis\nCAPITAL MANAGEMENT AND DIVIDEND POLICY”',
#    'gold_chapter': '',
#    'gold_page_id': 122.0,
#    '2019': '9,883',
#    '2018': '9,877'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_117',
#    'gold_field_name': 'Total Debt',
#    'gold_name_in_case': 'Net debt',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': 'Group Five-year Financial Summary',
#    'gold_chapter': '',
#    'gold_page_id': 110.0,
#    '2019': '9,883',
#    '2018': '9,877'}],
#  'E_PRO_4': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PRO_4',
#    'gold_field_name': 'EBITDA Margin',
#    'gold_name_in_case': 'EBITDA margin',
#    'gold_unit': '',
#    'gold_type': 'C',
#    'gold_table': 'Management Discussion and Analysis',
#    'gold_chapter': '',
#    'gold_page_id': 114.0,
#    '2019': '27.0%',
#    '2018': '29.2%'}],
#  'E_COV_8': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_COV_8',
#    'gold_field_name': 'Total Debt/EBITDA',
#    'gold_name_in_case': 'Net debt to EBITDA and share of associates’ pre-tax profits (number of times) ',
#    'gold_unit': '',
#    'gold_type': 'C',
#    'gold_table': '“Management Discussion and Analysis\nCAPITAL MANAGEMENT AND DIVIDEND POLICY”',
#    'gold_chapter': '',
#    'gold_page_id': 122.0,
#    '2019': '1.6',
#    '2018': '1.3'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_COV_8',
#    'gold_field_name': 'Total Debt/EBITDA',
#    'gold_name_in_case': 'Net debt to EBITDA and share of associates’ pre-tax profits (number of times) ',
#    'gold_unit': '',
#    'gold_type': 'C',
#    'gold_table': 'Group Five-year Financial Summary',
#    'gold_chapter': '',
#    'gold_page_id': 110.0,
#    '2019': '1.6',
#    '2018': '1.3'}],
#  'E_LIQ_4': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_LIQ_4',
#    'gold_field_name': 'Total Liabs/Total Net Worth',
#    'gold_name_in_case': '',
#    'gold_unit': '',
#    'gold_type': 'C',
#    'gold_table': '',
#    'gold_chapter': '',
#    'gold_page_id': '',
#    '2019': '',
#    '2018': ''}],
#  'E_LIQ_1': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_LIQ_1',
#    'gold_field_name': 'Current Ratio',
#    'gold_name_in_case': '',
#    'gold_unit': '',
#    'gold_type': 'C',
#    'gold_table': '',
#    'gold_chapter': '',
#    'gold_page_id': '',
#    '2019': '',
#    '2018': ''}],
#  'E_BS_4': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_4',
#    'gold_field_name': 'Trade and Other Receivables',
#    'gold_name_in_case': 'Trade and other receivables',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': 'Statements of Financial Position',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 142.0,
#    '2019': '5,992.7',
#    '2018': '5,813.7'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_4',
#    'gold_field_name': 'Trade and Other Receivables',
#    'gold_name_in_case': 'Trade and other receivables',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'R',
#    'gold_table': 'TRADE AND OTHER RECEIVABLES',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 192.0,
#    '2019': '5,992.7',
#    '2018': '5,813.7'}],
#  'E_BS_5': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_5',
#    'gold_field_name': 'Trade Debtors',
#    'gold_name_in_case': 'Trade receivables',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'TRADE AND OTHER RECEIVABLES',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 192.0,
#    '2019': '2,341.3',
#    '2018': '2,247.6'}],
#  'E_BS_6': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_6',
#    'gold_field_name': 'Notes Receivables',
#    'gold_name_in_case': '',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': '',
#    'gold_chapter': '',
#    'gold_page_id': '',
#    '2019': '',
#    '2018': ''}],
#  'E_BS_7': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_BS_7',
#    'gold_field_name': 'Other Receivables',
#    'gold_name_in_case': 'Other receivables',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'TRADE AND OTHER RECEIVABLES',
#    'gold_chapter': 'Notes to the Financial Statements',
#    'gold_page_id': 192.0,
#    '2019': '421.9',
#    '2018': '430.0'}],
#  'E_ACT_7': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_ACT_7',
#    'gold_field_name': 'Days of Sales Outstanding',
#    'gold_name_in_case': '',
#    'gold_unit': 'days',
#    'gold_type': 'C',
#    'gold_table': '',
#    'gold_chapter': '',
#    'gold_page_id': '',
#    '2019': '',
#    '2018': ''}]}

# %%
g_dict = (dict(list(grouped)))

# %%
{'2019': [{'gold_company_name': 'Singtel AR 2019.pdf',
   'gold_field_code': 'E_PL_1',
   'gold_field_name': 'Sales',
   'gold_name_in_case': 'Operating revenue',
   'gold_unit': 'millions, S$',
   'gold_type': 'E',
   'gold_table': 'Consolidated Income Statement',
   'gold_chapter': '',
   'gold_page_id': '140',
   'gold_value': '17,371.7',
   'gold_year': '2019'},
  {'gold_company_name': 'Singtel AR 2019.pdf',
   'gold_field_code': 'E_PL_1',
   'gold_field_name': 'Sales',
   'gold_name_in_case': 'Operating revenue',
   'gold_unit': 'millions, S$',
   'gold_type': 'E',
   'gold_table': 'OPERATING REVENUE',
   'gold_chapter': 'Notes to the Financial Statements',
   'gold_page_id': '170',
   'gold_value': '17,371.7',
   'gold_year': '2019'},
  {'gold_company_name': 'Singtel AR 2019.pdf',
   'gold_field_code': 'E_PL_1',
   'gold_field_name': 'Sales',
   'gold_name_in_case': 'Group operating revenue',
   'gold_unit': 'millions, S$',
   'gold_type': 'E',
   'gold_table': 'OPERATING REVENUE',
   'gold_chapter': 'Group Five-year Financial Summary',
   'gold_page_id': '110',
   'gold_value': '17,372',
   'gold_year': '2019'},
  {'gold_company_name': 'Singtel AR 2019.pdf',
   'gold_field_code': 'E_PL_1',
   'gold_field_name': 'Sales',
   'gold_name_in_case': 'Operating revenue',
   'gold_unit': 'millions, S$',
   'gold_type': 'E',
   'gold_table': 'SEGMENT INFORMATION',
   'gold_chapter': 'Notes to the Financial Statements',
   'gold_page_id': '231',
   'gold_value': '17,371.7',
   'gold_year': '2019'}]
# Out:
#   File "<ipython-input-1-db227c9854d7>", line 44
#     'gold_year': '2019'}]
#                          ^
# SyntaxError: unexpected EOF while parsing

# %%
df = pd.DataFrame({'a':[1,2,3],'b':[1,2,3]})

# %%
df
# Out:
#    a  b
# 0  1  1
# 1  2  2
# 2  3  3

# %%
df = df.rename(columns={'a':'A','b': 'B2'})

# %%
df
# Out:
#    A  B2
# 0  1   1
# 1  2   2
# 2  3   3

# %%
df.get_values()
# Out:
# 0    1
# 1    2
# 2    3
# Name: A, dtype: int64

# %%
a = {'a1':1, 'b2':2}
a
# Out:
# {'a1': 1, 'b2': 2}

# %%
list(a)
# Out:
# ['a1', 'b2']

# %%
k = [{'gold_company_name': 'Singtel AR 2019.pdf',
  'gold_field_code': 'E_PL_1',
  'gold_field_name': 'Sales',
  'gold_name_in_case': 'Operating revenue',
  'gold_unit': 'millions, S$',
  'gold_type': 'E',
  'gold_table': 'Consolidated Income Statement',
  'gold_chapter': '',
  'gold_page_id': 140.0,
  'gold_value': '17,371.7',
  'gold_year': '2019'},
     {'gold_company_name': 'Singtel AR 2019.pdf',
  'gold_field_code': 'E_PL_1',
  'gold_field_name': 'Sales',
  'gold_name_in_case': 'Operating revenue',
  'gold_unit': 'millions, S$',
  'gold_type': 'E',
  'gold_table': 'Consolidated Income Statement',
  'gold_chapter': '',
  'gold_page_id': 140.0,
  'value': '17,268.0',
  'gold_year': '2018'}, 
          {'gold_company_name': 'Singtel AR 2019.pdf',
  'gold_field_code': 'E_PL_3',
  'gold_field_name': 'Sales',
  'gold_name_in_case': 'Operating revenue',
  'gold_unit': 'millions, S$',
  'gold_type': 'E',
  'gold_table': 'Consolidated Income Statement',
  'gold_chapter': '',
  'gold_page_id': 140.0,
  'value': '17,268.0',
  'gold_year': '2018'},
     {'gold_company_name': 'Singtel AR 2019.pdf',
  'gold_field_code': 'E_PL_1',
  'gold_field_name': 'Sales',
  'gold_name_in_case': 'Operating revenue',
  'gold_unit': 'millions, S$',
  'gold_type': 'E',
  'gold_table': 'Consolidated Income Statement',
  'gold_chapter': '',
  'gold_page_id': 140.0,
  'value': '17,268.0',
  'gold_year': '2018'}
    ]

# %%
k
# Out:
# [{'gold_company_name': 'Singtel AR 2019.pdf',
#   'gold_field_code': 'E_PL_1',
#   'gold_field_name': 'Sales',
#   'gold_name_in_case': 'Operating revenue',
#   'gold_unit': 'millions, S$',
#   'gold_type': 'E',
#   'gold_table': 'Consolidated Income Statement',
#   'gold_chapter': '',
#   'gold_page_id': 140.0,
#   'gold_value': '17,371.7',
#   'gold_year': '2019'},
#  {'gold_company_name': 'Singtel AR 2019.pdf',
#   'gold_field_code': 'E_PL_1',
#   'gold_field_name': 'Sales',
#   'gold_name_in_case': 'Operating revenue',
#   'gold_unit': 'millions, S$',
#   'gold_type': 'E',
#   'gold_table': 'Consolidated Income Statement',
#   'gold_chapter': '',
#   'gold_page_id': 140.0,
#   'value': '17,268.0',
#   'gold_year': '2018'},
#  {'gold_company_name': 'Singtel AR 2019.pdf',
#   'gold_field_code': 'E_PL_3',
#   'gold_field_name': 'Sales',
#   'gold_name_in_case': 'Operating revenue',
#   'gold_unit': 'millions, S$',
#   'gold_type': 'E',
#   'gold_table': 'Consolidated Income Statement',
#   'gold_chapter': '',
#   'gold_page_id': 140.0,
#   'value': '17,268.0',
#   'gold_year': '2018'},
#  {'gold_company_name': 'Singtel AR 2019.pdf',
#   'gold_field_code': 'E_PL_1',
#   'gold_field_name': 'Sales',
#   'gold_name_in_case': 'Operating revenue',
#   'gold_unit': 'millions, S$',
#   'gold_type': 'E',
#   'gold_table': 'Consolidated Income Statement',
#   'gold_chapter': '',
#   'gold_page_id': 140.0,
#   'value': '17,268.0',
#   'gold_year': '2018'}]

# %%
import pydash
d = pydash.group_by(k, ["gold_field_code"])

# %%
d
# Out:
# {'E_PL_1': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': '',
#    'gold_page_id': 140.0,
#    'gold_value': '17,371.7',
#    'gold_year': '2019'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': '',
#    'gold_page_id': 140.0,
#    'value': '17,268.0',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': '',
#    'gold_page_id': 140.0,
#    'value': '17,268.0',
#    'gold_year': '2018'}],
#  'E_PL_3': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_3',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': '',
#    'gold_page_id': 140.0,
#    'value': '17,268.0',
#    'gold_year': '2018'}]}

# %%
pydash.group_by(d['2018'], ["gold_field_code"])
# Out:
# {'E_PL_1': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': '',
#    'gold_page_id': 140.0,
#    'value': '17,268.0',
#    'gold_year': '2018'},
#   {'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_1',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': '',
#    'gold_page_id': 140.0,
#    'value': '17,268.0',
#    'gold_year': '2018'}],
#  'E_PL_3': [{'gold_company_name': 'Singtel AR 2019.pdf',
#    'gold_field_code': 'E_PL_3',
#    'gold_field_name': 'Sales',
#    'gold_name_in_case': 'Operating revenue',
#    'gold_unit': 'millions, S$',
#    'gold_type': 'E',
#    'gold_table': 'Consolidated Income Statement',
#    'gold_chapter': '',
#    'gold_page_id': 140.0,
#    'value': '17,268.0',
#    'gold_year': '2018'}]}

# %%
t_list = [
        {
            "field_name": "sales",
            "field_code": "E_PL_1",
            "value": "45,743",
            "page_id": 1,
            "table_id": 1,
            "paragraph_id": None,
            "strategy": "rule"
        },
        {
            "field_name": "cost of sales",
            "field_code": "E_PL_2",
            "value": "(43,477)",
            "page_id": 1,
            "table_id": 1,
            "paragraph_id": None,
            "strategy": "rule"
        },
        {
            "field_name": "gross profit",
            "field_code": "E_PL_5",
            "value": "2,266",
            "page_id": 1,
            "table_id": 2,
            "paragraph_id": None,
            "strategy": "rule"
        },
        {
            "field_name": "interest expense",
            "field_code": "E_PL_21",
            "value": "(339)",
            "page_id": 1,
            "table_id": 1,
            "paragraph_id": None,
            "strategy": "rule"
        },
        {
            "field_name": "taxation",
            "field_code": "E_PL_37",
            "value": "(179)",
            "page_id": 1,
            "table_id": 1,
            "paragraph_id": None,
            "strategy": "rule"
        }
    ]

# %%
pydash.group_by(t_list, ["field_code"])
# Out:
# {'E_PL_1': [{'field_name': 'sales',
#    'field_code': 'E_PL_1',
#    'value': '45,743',
#    'page_id': 1,
#    'table_id': 1,
#    'paragraph_id': None,
#    'strategy': 'rule'}],
#  'E_PL_2': [{'field_name': 'cost of sales',
#    'field_code': 'E_PL_2',
#    'value': '(43,477)',
#    'page_id': 1,
#    'table_id': 1,
#    'paragraph_id': None,
#    'strategy': 'rule'}],
#  'E_PL_5': [{'field_name': 'gross profit',
#    'field_code': 'E_PL_5',
#    'value': '2,266',
#    'page_id': 1,
#    'table_id': 2,
#    'paragraph_id': None,
#    'strategy': 'rule'}],
#  'E_PL_21': [{'field_name': 'interest expense',
#    'field_code': 'E_PL_21',
#    'value': '(339)',
#    'page_id': 1,
#    'table_id': 1,
#    'paragraph_id': None,
#    'strategy': 'rule'}],
#  'E_PL_37': [{'field_name': 'taxation',
#    'field_code': 'E_PL_37',
#    'value': '(179)',
#    'page_id': 1,
#    'table_id': 1,
#    'paragraph_id': None,
#    'strategy': 'rule'}]}
